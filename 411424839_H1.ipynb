# %% [markdown]
# <a href="https://colab.research.google.com/github/erictye0907-hue/115-1/blob/main/411424839_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("請輸入擁有多少金幣:"))
y=int(input("請輸入獲得金幣數量:"))
z=x+y
print(f"任務完成！你現在有{z}枚金幣")
# Out:
# 請輸入擁有多少金幣:500
# 請輸入獲得金幣數量:250
# 任務完成！你現在有750枚金幣
